# %%
import pandas as pd
import football_datareader as fd

def strip_end(s):
    if s[-1] == '+':
        s = s[0:-1]
    if s[-1] == '*':
        s = s[0:-1]
    return s

# %%
fd.pull_hist_stats_by_name('James White').head()
# Out:
#      Year   Age   Tm  Pos  No.   G   GS  Tgt   Rec    Yds ...   Y/A  Y/G.1  \
# 0    2014  22.0  NWE  NaN   28   3    0    5     5   23.0 ...   4.2   12.7
# 1    2015  23.0  NWE   rb   28  14    1   54    40  410.0 ...   2.5    4.0
# 2    2016  24.0  NWE   rb   28  16    4   86    60  551.0 ...   4.3   10.4
# 3    2017  25.0  NWE   rb   28  14    4   72    56  429.0 ...   4.0   12.2
# 4  Career   NaN  NaN  NaN   47   9  217  161  1413    8.8 ...   9.2    2.4
#
#      A/G  Touch   APYd   Y/Tch  YScm  RRTD  Fmb   AV
# 0    3.0     14   61.0     4.4    61     0    0  1.0
# 1    1.6     62  466.0     7.5   466     6    0  5.0
# 2    2.4    101  745.0     7.4   717     5    0  7.0
# 3    3.1     99  600.0     6.1   600     3    0  6.0
# 4  276.0   1872    6.8  1844.0    14     0   19  NaN
#
# [5 rows x 30 columns]

# %%
rb = pd.read_html(fd.PFR.format('years/2017/rushing'), skiprows=1, header=0)
rb_s = rb[0]
columns = list(rb_s.columns)
columns[1] = 'Nm'
rb_s.columns = columns
rb_s= rb_s.dropna()
rb_s['Nm'] = rb_s['Nm'].apply(strip_end)
rb_s.head()
# Out:
# /Users/avimhjn/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#   Rk             Nm   Tm Age Pos   G  GS  Att   Yds  TD ... Lng.1  R/G Y/G.1  \
# 0  1   Le'Veon Bell  PIT  25  RB  15  15  321  1291   9 ...    42  5.7  43.7
# 1  2   LeSean McCoy  BUF  29  RB  16  16  287  1138   6 ...    39  3.7  28.0
# 2  3  Melvin Gordon  LAC  24  RB  16  16  284  1105   8 ...    49  3.6  29.8
# 3  4    Todd Gurley  LAR  23  RB  15  15  279  1305  13 ...    80  4.3  52.5
# 4  5  Jordan Howard  CHI  23  RB  16  16  276  1122   9 ...    12  1.4   7.8
#
#    Ctch% Touch  APYd Y/Tch  YScm RRTD Fmb
# 0  80.2%   406  1946   4.8  1946   11   3
# 1  76.6%   346  1586   4.6  1586    8   3
# ...

# %%
fd.pull_hist_stats_by_name('LeSean McCoy')['Yds'].plot()

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-d8fa9427a3fe> in <module>()
# ----> 1 fd.pull_hist_stats_by_name('Le\'Veon Bell')
#
# ~/football_datareader.py in pull_hist_stats_by_name(name)
#      21     first_last = name.split()
#      22     print(first_last)
# ---> 23     plr_stng = "players/"+first_last[1][0]+"/"+first_last[1][0:4]+first_last[0][0:2]
#      24     print(plr_stng)
#      25     num=find_player(name, plr_stng)
#
# ~/football_datareader.py in find_player(name, plr_stng)
#      32     while plr_name != name:
#      33         num_st = str(num)
# ---> 34         if num < 10:
#      35             num_st = '0' + num_st
#      36         fp = urllib.request.urlopen(PFR.format(plr_stng + num_st))
#
# ~/anaconda3/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
# ...

# %%
parser.data_sources
# Out:
# ['LeVeon Bell']
